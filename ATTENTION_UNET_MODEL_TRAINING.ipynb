tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_14.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_28.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_28.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_22_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_22_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_23_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_23_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_9_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_9_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_8_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_8_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_48_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_48_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_49_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_49_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_10.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_10.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_38.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_38.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_39.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_39.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_11.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_11.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_42_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_42_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_43_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_43_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_3_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_3_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_2_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_2_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_13.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_13.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_35_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_35_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_12.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_12.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_34_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_34_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_51_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_51_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_50_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_50_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_18_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_18_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_19_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_19_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_23.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_23.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_37.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_37.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_36.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_36.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_22.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_22.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_26_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_26_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_27_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_27_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_12_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_12_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_13_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_13_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_34.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_34.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_20.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_20.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_21.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_21.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_35.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_35.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_65_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_65_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_64_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_64_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_7_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_7_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_6_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_6_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_31.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_31.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_25.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_25.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_46_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_46_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_47_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_47_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_19.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_19.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_18.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_18.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_24.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_24.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_30.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_30.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_31_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_31_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_30_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_30_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_26.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_26.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_32.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_32.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_33.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_33.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_27.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_27.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_72_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_72_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_73_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_73_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_41_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_41_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_40_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_40_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_1_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_1_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_68.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_68.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_40.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_40.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_54.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_54.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_55.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_55.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_41.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_41.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_69.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_69.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_36_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_36_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_37_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_37_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_57.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_57.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_43.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_43.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_42.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_42.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_56.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_56.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_56_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_56_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_57_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_57_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_52.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_52.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_46.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_46.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_8.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_8.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_9.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_9.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_47.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_47.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_53.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_53.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_68_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_68_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_69_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_69_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_21_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_21_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_20_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_20_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_15_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_15_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_14_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_14_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_45.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_45.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_51.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_51.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_50.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_50.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_44.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_44.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_62_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_62_mask.tif
#   inflating: Data/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_63_mask.tif
#   inflating: __MACOSX/Data/TCGA_FG_A60K_20040224/._TCGA_FG_A60K_20040224_63_mask.tif

# %%
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.4.15)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: scikit-image>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.24.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (2.9.2)
# Requirement already satisfied: albucore>=0.0.15 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.16)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.2.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (4.12.2)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (3.4)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (0.4)

# %%
import os
import cv2
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import albumentations as A
from albumentations.pytorch import ToTensorV2

# Define the CLAHE preprocessing function
def apply_clahe(image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    return clahe.apply(image)

# Custom dataset class for Brain MRI images and masks
class BrainMRIDataset(Dataset):
    def __init__(self, image_paths, mask_paths, transform=None):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # Load and preprocess the image and mask
        image = cv2.imread(self.image_paths[idx], cv2.IMREAD_GRAYSCALE)
        mask = cv2.imread(self.mask_paths[idx], cv2.IMREAD_GRAYSCALE)

        # Apply CLAHE to the image
        image = apply_clahe(image)

        # Resize the image and mask to (256, 256) to match U-Net input
        #image = cv2.resize(image, (256, 256))
        #mask = cv2.resize(mask, (256, 256))

        # Normalize the image to [0, 1]
        image = image / 255.0

        # Binarize the mask
        mask = np.where(mask > 0, 1, 0).astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']
        image = image.clone().detach().float()  # Convert image to tensor and add channel dimension
        mask = mask.unsqueeze(0)  # Convert mask to tensor and add channel dimension
        return image, mask

# Function to load the images and masks
def load_data(image_dir):
    images = []
    masks = []

    for folder in os.listdir(image_dir):
        folder_path = os.path.join(image_dir, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                if 'mask' in file:
                    masks.append(file_path)
                else:
                    images.append(file_path)
    return images, masks

# Define transformations (augmentation + tensor conversion)
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Rotate(limit=20, p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.GaussianBlur(p=0.2),
    ToTensorV2()
])
val_transform = A.Compose([
    ToTensorV2()
])

# Load images and masks
image_dir = '/content/Data'  # Change this to your actual image directory
images, masks = load_data(image_dir)

# Split dataset into train and validation
train_images, val_images, train_masks, val_masks = train_test_split(images, masks, test_size=0.2, random_state=42)

train_dataset = BrainMRIDataset(train_images, train_masks, transform=train_transform)
val_dataset = BrainMRIDataset(val_images, val_masks,transform=val_transform)

# Data loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

dataloaders = {'train': train_loader, 'val': val_loader}

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Define a convolution block with two convolution layers
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        return x

# Define the attention block
class AttentionBlock(nn.Module):
    def __init__(self, g_channels, x_channels, intermediate_channels):
        super(AttentionBlock, self).__init__()
        self.W_g = nn.Conv2d(g_channels, intermediate_channels, kernel_size=1)
        self.W_x = nn.Conv2d(x_channels, intermediate_channels, kernel_size=1)
        self.psi = nn.Conv2d(intermediate_channels, 1, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, g, x):
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        psi = self.relu(g1 + x1)
        psi = self.sigmoid(self.psi(psi))
        return x * psi

# Define the Attention U-Net model
class AttentionUNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(AttentionUNet, self).__init__()

        # Downsampling path
        self.enc1 = ConvBlock(in_channels, 64)
        self.enc2 = ConvBlock(64, 128)
        self.enc3 = ConvBlock(128, 256)
        self.enc4 = ConvBlock(256, 512)

        # Bottleneck
        self.bottleneck = ConvBlock(512, 1024)

        # Upsampling path
        self.upconv4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.att4 = AttentionBlock(512, 512, 256)
        self.dec4 = ConvBlock(1024, 512)

        self.upconv3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.att3 = AttentionBlock(256, 256, 128)
        self.dec3 = ConvBlock(512, 256)

        self.upconv2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.att2 = AttentionBlock(128, 128, 64)
        self.dec2 = ConvBlock(256, 128)

        self.upconv1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.att1 = AttentionBlock(64, 64, 32)
        self.dec1 = ConvBlock(128, 64)

        # Output layer for segmentation
        self.conv_out = nn.Conv2d(64, out_channels, kernel_size=1)

    def forward(self, x):
        # Encoder path
        enc1 = self.enc1(x)
        enc2 = self.enc2(F.max_pool2d(enc1, 2))
        enc3 = self.enc3(F.max_pool2d(enc2, 2))
        enc4 = self.enc4(F.max_pool2d(enc3, 2))

        # Bottleneck
        bottleneck = self.bottleneck(F.max_pool2d(enc4, 2))

        # Decoder path
        up4 = self.upconv4(bottleneck)
        att4 = self.att4(up4, enc4)
        dec4 = self.dec4(torch.cat([up4, att4], dim=1))

        up3 = self.upconv3(dec4)
        att3 = self.att3(up3, enc3)
        dec3 = self.dec3(torch.cat([up3, att3], dim=1))

        up2 = self.upconv2(dec3)
        att2 = self.att2(up2, enc2)
        dec2 = self.dec2(torch.cat([up2, att2], dim=1))

        up1 = self.upconv1(dec2)
        att1 = self.att1(up1, enc1)
        dec1 = self.dec1(torch.cat([up1, att1], dim=1))

        # Output layer for segmentation
        out = self.conv_out(dec1)
        return out

# %%
import torch.optim as optim
from tqdm import tqdm

# Dice coefficient metric
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)
    intersection = (y_true_f * y_pred_f).sum()
    return (2. * intersection + smooth) / (y_true_f.sum() + y_pred_f.sum() + smooth)

# Loss function: BCE + Dice Loss
def bce_dice_loss(preds, targets):
    bce = F.binary_cross_entropy_with_logits(preds, targets)
    dice = dice_coef(torch.sigmoid(preds), targets)
    return bce - torch.log(dice)

# Training function
def train_model(model, dataloaders, optimizer, num_epochs=25):
    best_dice = 0.0
    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        model.train()
        running_loss = 0.0
        running_dice = 0.0

        for images, masks in tqdm(dataloaders['train']):
            images = images.to(device)
            masks = masks.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = bce_dice_loss(outputs, masks)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            running_dice += dice_coef(torch.sigmoid(outputs), masks).item() * images.size(0)

        epoch_loss = running_loss / len(dataloaders['train'].dataset)
        epoch_dice = running_dice / len(dataloaders['train'].dataset)

        print(f'Training Loss: {epoch_loss:.4f} | Training Dice: {epoch_dice:.4f}')

        # Evaluate model on validation set
        model.eval()
        val_dice = 0.0
        with torch.no_grad():
            for images, masks in dataloaders['val']:
                images = images.to(device)
                masks = masks.to(device)
                outputs = model(images)
                val_dice += dice_coef(torch.sigmoid(outputs), masks).item() * images.size(0)

        val_dice /= len(dataloaders['val'].dataset)
        print(f'Validation Dice: {val_dice:.4f}')

        if val_dice > best_dice:
            best_dice = val_dice
            torch.save(model.state_dict(), 'best_model.pth')
            print(f'Saving best model with Dice: {best_dice:.4f}')

        attention_unet_checkpoint = {
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_dice': best_dice
        }
        torch.save(attention_unet_checkpoint, f'/content/drive/MyDrive/ATTENTION_U_NET/attention_unet_checkpoint_epoch_{epoch+1}.pth')

    return best_dice

# Initialize DataLoader, Model, Optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Instantiate both models
attention_unet = AttentionUNet(in_channels=1, out_channels=1).to(device)

# Optimizers
optimizer_attention_unet = optim.Adam(attention_unet.parameters(), lr=1e-4)

dataloaders = {
    'train': train_loader,
    'val': val_loader
}

# best_dice_attention_unet = train_model(attention_unet, dataloaders, optimizer_attention_unet, num_epochs=5)

# print(f"Best Dice score for Attention U-Net: {best_dice_attention_unet}")

# %%
from tqdm import tqdm

# Evaluation function to compute metrics
def evaluate_model(model, dataloader):
    model.eval()
    dice_total = 0.0
    iou_total = 0.0
    with torch.no_grad():
        for images, masks in tqdm(dataloader):
            images = images.to(device)
            masks = masks.to(device)

            # Forward pass
            outputs = model(images)
            preds = torch.sigmoid(outputs)  # Apply sigmoid to get probabilities
            preds = (preds > 0.5).float()  # Binarize predictions at 0.5 threshold

            # Calculate Dice coefficient
            dice = dice_coef(preds, masks).item()
            dice_total += dice * images.size(0)

            # Calculate IoU
            intersection = (preds * masks).sum(dim=(2, 3))
            union = (preds + masks).sum(dim=(2, 3)) - intersection
            iou = (intersection + 1e-6) / (union + 1e-6)
            iou_total += iou.mean().item() * images.size(0)

    dice_avg = dice_total / len(dataloader.dataset)
    iou_avg = iou_total / len(dataloader.dataset)
    return dice_avg, iou_avg

# %%
import torch
from torch.optim import Adam

# Ensure the Attention U-Net architecture is already defined
# If not, define the AttentionUNet class here

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize the Attention U-Net model
attention_unet = AttentionUNet(in_channels=1, out_channels=1).to(device)

# Load the saved checkpoint
checkpoint = torch.load('/content/drive/MyDrive/ATTENTION_U_NET/attention_unet_checkpoint_epoch_3.pth')

# Load the model state dict
attention_unet.load_state_dict(checkpoint['model_state_dict'])

# If optimizer state is needed (not mandatory for evaluation):
optimizer = Adam(attention_unet.parameters(), lr=1e-4)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# Set the model to evaluation mode
attention_unet.eval()
# Out:
# <ipython-input-23-4f59f01116bf>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('/content/drive/MyDrive/ATTENTION_U_NET/attention_unet_checkpoint_epoch_3.pth')
# AttentionUNet(
#   (enc1): ConvBlock(
#     (conv1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (enc2): ConvBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (enc3): ConvBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (enc4): ConvBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (bottleneck): ConvBlock(
#     (conv1): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (upconv4): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#   (att4): AttentionBlock(
#     (W_g): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (W_x): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (psi): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU()
#     (sigmoid): Sigmoid()
#   )
#   (dec4): ConvBlock(
#     (conv1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (upconv3): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (att3): AttentionBlock(
#     (W_g): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (W_x): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (psi): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU()
#     (sigmoid): Sigmoid()
#   )
#   (dec3): ConvBlock(
#     (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (upconv2): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (att2): AttentionBlock(
#     (W_g): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (W_x): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (psi): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU()
#     (sigmoid): Sigmoid()
#   )
#   (dec2): ConvBlock(
#     (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (upconv1): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (att1): AttentionBlock(
#     (W_g): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#     (W_x): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#     (psi): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU()
#     (sigmoid): Sigmoid()
#   )
#   (dec1): ConvBlock(
#     (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (conv_out): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
import numpy as np
from tqdm import tqdm

# Assuming you have a DataLoader for test images and masks
# Modify the `test_loader` if necessary
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# Evaluation function for the test set
def evaluate_model(model, dataloader):
    model.eval()  # Set model to evaluation mode
    total_dice = 0.0

    with torch.no_grad():
        for images, masks in tqdm(dataloader):
            images = images.to(device)
            masks = masks.to(device)

            # Forward pass
            outputs = model(images)
            outputs = torch.sigmoid(outputs)  # Apply sigmoid to get probabilities
            preds = (outputs > 0.5).float()  # Threshold the probabilities to get binary predictions

            # Calculate Dice coefficient
            dice = dice_coef(preds, masks)
            total_dice += dice.item()

    # Average Dice score
    avg_dice = total_dice / len(dataloader)
    print(f'Average Dice Coefficient: {avg_dice:.4f}')
    return avg_dice

# Evaluate the loaded Attention U-Net model
evaluate_model(attention_unet, test_loader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-683b45e54da3> in <cell line: 6>()
#       4 # Assuming you have a DataLoader for test images and masks
#       5 # Modify the `test_loader` if necessary
# ----> 6 test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
#       7
#       8 # Evaluation function for the test set
#
# NameError: name 'test_dataset' is not defined
